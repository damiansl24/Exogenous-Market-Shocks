# %% [markdown]
# **This is the exploratory notebook for the Exogenous Shocks project.**

# %%
# %load_ext autoreload
# %autoreload 2

import os 
import sys

sys.path.append(os.path.abspath(".."))

from src.data import load_stock_data as lsd
from src.variance_msr import covariance, variance
from src.volatility import beta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# importing data: GDAXI and GSPC for example. 

market_df = lsd(["^GSPC", "^GDAXI"], "2000-01-01", "2025-01-01")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
mkt_cov = covariance(market_df, 30)

# %%
plt.figure(figsize = (10,6))

plt.plot(mkt_cov)

# %% [markdown]
# Thus, the DAX and S&P 500 do not correlate with one another significantly. Despite that, spikes post-2008 in covariance are worth investigation. They have no linear correlation except after some large ish events. Furthermore, how can we define an optimal window? 30 days seems to be the academic / industry standard, but I'm wondering if lowering the resolution can provide a more generalizeable view of variance...
